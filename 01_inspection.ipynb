# %% [markdown]
# # Assignment 1: Inspecting the Dataset

# %% [markdown]
# In this first assignment, we will get to know the dataset that we will be using throughout. You can find the assignment tasks at the bottom of this document.
#
# Our dataset consists of short texts (article abstracts) from the [PubMed](https://www.ncbi.nlm.nih.gov/pubmed/) database of scientific publications in the Life Science domain. As the full dataset consists of millions of documents, we are using just a small subset, namely all publications that contain the word "Recognition" in their title or abstract. You can download that dataset in the form of four files (`emotion_Summaries.pkl.bz2`, etc.) from Canvas. Save these four files in a directory called `data` (do not unpack them, but save them as .bz2 files!), which should be a sub-directory of the one that contains this notebook file.

# %% [markdown]
# ## Importing some Libraries

# %%
from collections import namedtuple, defaultdict, Counter
import pickle, bz2

# %% [markdown]
# ## Loading the Dataset

# %%
Summaries_file = 'recognition_Summaries.pkl.bz2'
Summaries = pickle.load( bz2.BZ2File( Summaries_file, 'rb' ) )

# %% [markdown]
# To make it easier to access the data, we convert here paper entries into [named tuples](http://docs.python.org/3/library/collections.html#collections.namedtuple). This will allow us to refer to fields by keyword ( like `var.year`), rather than index (like `var[2]`).

# %%
paper = namedtuple( 'paper', ['title', 'authors', 'year', 'doi'] )

for (id, paper_info) in Summaries.items():
    Summaries[id] = paper( *paper_info )

# %%
Summaries[39432831]
# Out:
# paper(title='Structure and Energetics of PET-Hydrolyzing Enzyme Complexes: A Systematic Comparison from Molecular Dynamics Simulations.', authors=['Berselli A', 'Menziani MC', 'Muniz-Miranda F'], year=2024, doi='10.1021/acs.jcim.4c01369')

# %%
Summaries[39432831].title
# Out:
# 'Structure and Energetics of PET-Hydrolyzing Enzyme Complexes: A Systematic Comparison from Molecular Dynamics Simulations.'

# %% [markdown]
# ## Dataset Statistics

# %% [markdown]
# The two lines below will install [matplotlib](http://matplotlib.org/) and [NumPy](http://www.numpy.org/), if they are not installed already (if that doesn't work, you might have to download and install them from [here](http://matplotlib.org/downloads.html) and [here](http://sourceforge.net/projects/numpy/files/NumPy/1.10.1/)). We will need these libraries for drawing diagrams and analyzing the data below.

# %%
! pip install --user matplotlib
! pip install --user numpy
# Out:
# Requirement already satisfied: matplotlib in /Users/jaspreetsingh/opt/anaconda3/lib/python3.9/site-packages (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jaspreetsingh/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/jaspreetsingh/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jaspreetsingh/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/jaspreetsingh/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in /Users/jaspreetsingh/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/jaspreetsingh/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=8 in /Users/jaspreetsingh/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/jaspreetsingh/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jaspreetsingh/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/jaspreetsingh/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (5.2.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/jaspreetsingh/opt/anaconda3/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.11.0)
# Requirement already satisfied: six>=1.5 in /Users/jaspreetsingh/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: numpy in /Users/jaspreetsingh/opt/anaconda3/lib/python3.9/site-packages (1.26.4)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# show plots inline within the notebook
# %matplotlib inline
# set plots' resolution
plt.rcParams['savefig.dpi'] = 100

# %% [markdown]
# ### Papers per Year

# %% [markdown]
# First, we will try to find out how many papers in the dataset were published per year. We are using the [Counter](https://docs.python.org/3/library/collections.html#collections.Counter) class for this.

# %%
paper_years = [ p.year for p in Summaries.values() ]
print(set(paper_years))
papers_per_year = sorted( Counter(paper_years).items() )

print(len(Summaries))
print('Number of papers in the dataset per year for the past decade:')
print(papers_per_year[-10:])
# Out:
# {1836, 1837, 1840, 1867, 1868, 1871, 1873, 1876, 1880, 1881, 1882, 1884, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025}
# 481216
# Number of papers in the dataset per year for the past decade:
# [(2016, 17385), (2017, 17907), (2018, 18598), (2019, 19328), (2020, 20943), (2021, 23238), (2022, 23894), (2023, 23044), (2024, 22564), (2025, 41)]

# %%
authors_perYears = [ p.authors for p in Summaries.values() ]
authors_perYears
# Out:
# [['van Dam-Mieras MC', 'Slotboom AJ', 'Pieterson WA', 'de Haas GH'],
#  ['Freedman P', 'Smith EC'],
#  ['Roversi GD', 'Canussio V', 'Spennacchio M'],
#  ['Guggenbichler JP', 'Stickler GB'],
#  ['Johnson G'],
#  ['Dalziel K'],
#  ['Crumpton MJ', 'Allan D', 'Auger J', 'Green NM', 'Maino VC'],
#  ['Gerisch G', 'Hülser D', 'Malchow D', 'Wick U'],
#  ['Truter MR'],
#  ['Godeau P', 'Wechsher B', 'Bletry O', 'Louvel A', 'Fanjoux J'],
#  ['Di Natale P', 'Schechter AN', 'Castronuovo Lepore G', 'De Lorenzo F'],
#  ['Uphoff DE'],
#  ['Orcutt TJ', 'Pruitt BA'],
#  ['Wilkins RA', 'De Lacey GJ', 'Flor R', 'Taylor S'],
#  ['Barker EG Jr', 'Rosenbaum HD', 'Selke AC Jr', 'Henderson D', 'Hildner JH'],
#  ['Komaroff AL',
#   'Flatley M',
#   'Browne C',
#   'Sherman H',
#   'Fineberg SE',
#   'Knopp RH'],
#  ['van Wyk CW'],
#  ['Krauss G', 'Peters F', 'Maass G'],
#  ['Taub HA', 'Eisenberg L'],
#  ['Scheider W', 'Dintzis HM', 'Oncley JL'],
#  ['Lefkowitz RJ'],
#  ['Scherer WF', 'Anderson K', 'Pancake BA', 'Dickerman RW', 'Ordonez JV'],
#  ['Ogata ES', 'Gregory GA', 'Kitterman JA', 'Phibbs RH', 'Tooley WH'],
#  ['Nakanishi S', 'Tanabe T', 'Horikawa S', 'Numa S'],
#  ['Rozovsky LE'],
#  ['Rhodes DJ'],
#  ['Riesner D', 'Pingoud A', 'Boehme D', 'Peters F', 'Maass G'],
#  ['Cartron JP', 'Ropars C', 'Calkovská Z', 'Salmon C'],
#  ['Trautwein H'],
#  ['Miller R'],
#  ['Grebe SC', 'Streilein JW'],
#  ['Pandit SK', 'Heisterkamp DV', 'Cohen PJ'],
#  ['Polk HC Jr'],
#  ['Walz FG Jr'],
#  ['van Wezel FM', 'Slotboom AJ', 'de Haas GH'],
#  ['Starke H'],
#  ['Shinitzky M', 'Hazum E', 'Fridkin M'],
#  ['Sutherland DC', 'Wilson JD'],
#  ['Marr D'],
#  ['Geddes IC'],
#  ['Guilley H', 'Jonard G', 'Richards KE', 'Hirth L'],
#  ['Hohn T', 'Wurtz M', 'Hohn B'],
#  ['Isenman DE', 'Ellerson JR', 'Painter RH', 'Dorrington KJ'],
#  ['Rosenblum WI', 'El-Sabban F'],
#  ['Reif U', 'Winterhoff U', 'Doerfler W'],
#  ['Cássaro CM', 'Dietrich CP'],
#  ['Belchev B', 'Yaneva M'],
#  ['Kolhouse JF', 'Allen RH'],
#  ['Lee SM'],
#  ['Paglieroni T', 'MacKenzie MR'],
#  ['Bungo MW', 'Beetham WP Jr'],
#  ["Man'ko VM", 'Ptrov RV', 'Rudneva TB'],
#  ['Skyler JS', 'Baumann G', 'Chrambach A'],
#  ['Hood AF', 'Soter NA', 'Rappeport J', 'Gigli I'],
#  ['Breda G', 'Zattoni F', 'Artibani W', 'Brunetti A', 'Vancini P'],
#  ['Benedetti A', 'Casini AF', 'Ferrali M'],
#  ['Lallier R'],
#  ['Fahmy K'],
#  ['Jasnis MA', 'Klein S', 'De Bonaparte YP', 'De Daga SO', 'De Pirosky RR'],
#  ['McCullagh P'],
#  ['Hays BJ', 'Mockelstrom NR'],
#  ['Cogen FC', 'Mayock RL', 'Zweiman B'],
#  ['Alexander M', 'Kampf D'],
#  ['Richter R', 'Hohl M', 'Hammacher K', 'Lüscher KP', 'Stucki D'],
#  ['Galloon S', 'Gale GD', 'Lancee WJ'],
#  ['Selhub J', 'Dhar GJ', 'Rosenberg IH'],
#  ['Forêt M', 'Schmidt R', 'Reichert U'],
#  ['Kobayashi RM'],
#  ['Brondz BD'],
#  ['Grady GF',
#   'Maxfield HK',
#   'Hildreth SW',
#   'Timperi RJ Jr',
#   'Gilfillan RF',
#   'Rosenau BJ',
#   'Francy DB',
#   'Calisher CH',
#   'Marcus LC',
#   'Madoff MA'],
#  ['Korda AR'],
#  ['Marr D', 'Nishihara HK'],
#  ['Smith MC'],
#  ['Mnatsakanian IuA', 'Pospelov LE', 'Egorov IK'],
#  ['Wiesmann UN', 'Di Donato S'],
#  ['Kinsky RG', 'Duc HT', 'Fuensalida E'],
#  ['Brondz BD'],
#  ['Shohat B', 'Kirson I', 'Lavie D'],
#  ['Paquet C', 'Gaillard JM', 'Tissot R'],
#  ['Bunodière M'],
#  ['Levi AJ', 'Chalmers DM'],
#  ['Becker DB', 'Needleman HL', 'Kotelchuck M'],
#  ['Belsole RJ', 'Lister GD', 'Kleinert HE'],
#  ['Mann SC', 'Boger WP'],
#  ['Alford BA', 'Peoples WM', 'Resnick JS', "L'Heureux PR"],
#  ['Casey DE'],
#  ['Dunn J', 'Wold S'],
#  ['Lapin V'],
#  ['Warr GW', 'Marchalonis JJ'],
#  ['Dunn WJ 3rd', 'Wold S'],
#  ['Schramm VL Jr', 'Myers EN', 'Rogerson DR'],
#  ['Dulaney JT'],
#  ['Javitt NB'],
#  ['Bonnardot JP',
#   'Marsac J',
#   'Richard P',
#   'Bonvoisin R',
#   'Brulé M',
#   'Bouchoucha S',
#   'Deligné P'],
#  ['Jenner E'],
#  ['Tikchonenko TI', 'Karamov EV', 'Zavizion BA', 'Naroditsky BS'],
#  ['Matsuo F', 'Ajax ET'],
#  ['Zakhireh B', 'Block LH', 'Root RK'],
#  [],
#  [],
#  ['Smith DC'],
#  ['Bannister LH'],
#  ['Beringer JE', 'Brewin N', 'Johnston AW', 'Schulman HM', 'Hopwood DA'],
#  [],
#  ['Faulk WP', 'Galbraith GM'],
#  ['Subba Rao DS', 'Grogan JB'],
#  ['Brown CE', 'Margolis FL', 'Williams TH', 'Pitcher RG', 'Elgar GJ'],
#  ['Babakov AV', 'Terekhov OP', 'Yanenko AS'],
#  ['Andrassy RJ', 'Murthy S', 'Woolley MM'],
#  ['Lawther PJ'],
#  ['Teräväinen H', 'Calne DB'],
#  ['Frishman W', 'Jacob H', 'Eisenberg E', 'Ribner H'],
#  ['Armstrong B'],
#  ['Ruffing MA'],
#  ['Beck FM', 'Kaul TJ', 'Weaver JM 2nd'],
#  ['Ofengand J'],
#  ['Fenney RJ'],
#  ['Kirkwood TB', 'Holliday R'],
#  ['Ram CV', 'Engelman K'],
#  ['Haertlé T', 'Wohlrab F', 'Guschlbauer W'],
#  ['Smith IM', 'Baskerville AJ'],
#  ['Bigger CH', 'Runyan R'],
#  ['Vizkelety T', 'Rényi-Vámos A'],
#  ['Mills CF'],
#  ['Comfort A'],
#  ['Geissler HG'],
#  ['Mitolo-Chieppa D', 'Cagnazzo F'],
#  ['Shoemaker WC',
#   'Hopkins JA',
#   'Greenfield S',
#   'Chang PC',
#   'Umof P',
#   'Shabot MM',
#   'Spenler CW',
#   'State D'],
#  ['Tsuchiya T', 'Wilson TH'],
#  ['Fleischman JB', 'Eisen HN'],
#  ['Tanaka H'],
#  ['Girard JP', 'Cuevas M'],
#  ['Janeway CA', 'Cohen BE', 'Ben-Sasson SZ', 'Paul WE'],
#  ['Gearhart PJ', 'Sigal NH', 'Klinman NR'],
#  ['Basten A', 'Miller JF', 'Abraham R'],
#  ['Sumarokov AV', 'Mikhailov AA'],
#  ['McSwiggan DA', 'Taylor CE'],
#  ['Librach IM'],
#  ['Flavell RA', 'Sabo DL', 'Bandle EF', 'Weissmann C'],
#  ['Vera Z', 'Mason DT', 'Awan NA', 'Hiliard G', 'Massumi RA'],
#  ['Sizemore GW', 'Hpeath H 3rd', 'Larson JM'],
#  ['Stewart GT'],
#  ['Medeiros AA', "O'Brien TF"],
#  ['Bezjak V'],
#  ['Amos DB'],
#  ['Forssman H'],
#  ['Marriott HJ'],
#  ['Nossal GJ', 'Pike BL'],
#  ['Winchester RJ', 'Wernet P', 'Kunkel HG', 'Dupont B', 'Jersild C', 'Fu SM'],
#  ['Frbes JT', 'Nakaw Y', 'Smith RT'],
#  ['Johnson PM', 'Watkins J', 'Wolborow EJ'],
#  ['Stimson WH'],
#  ['Finn R'],
#  ['Culp DA'],
#  ['Gilliland PF'],
#  ['van Rood JJ', 'van Leeuwen A', 'Keuning JJ', 'van Oud Alblas AB'],
#  ['Phillips SM', 'Carpenter CB', 'Lane P'],
#  ['Shevach EM', 'Finkelman F', 'Ben-Sasson SZ', 'Green I', 'Paul WE'],
#  ['Stokes EJ'],
#  ['Hutchison JG', 'Geddes AM'],
#  ['Janeway CA Jr', 'Sakato N', 'Eisen HN'],
#  ['Bell GI'],
#  ['Gilbert HS', 'Ornstein L'],
#  ['Marsh WL'],
#  ['Doherty PC', 'Zinkernagel RM'],
#  ['Eglinton G', 'Simoneit BR', 'Zoro JA'],
#  ['Bütler R'],
#  ['Weinberg H'],
#  ['Courchesne E', 'Hillyard SA', 'Galambos R'],
#  ['Zhirmunskaya EA', 'Bein ES', 'Volkov VN', 'Voitenko GA', 'Konyukhova GR'],
#  ['Bordenave GR'],
#  ['Wivel NA', 'Smith GH', 'Ozer HL'],
#  ['Bullock WW', 'Katz DH', 'Benacerraf B'],
#  ['Diener E', 'Langman RE'],
#  ['Johnson TS', 'Hudson JL', 'Feldman ME', 'Irvin GL 3rd'],
#  ['Mason D', 'Lauder I', 'Rutovitz D', 'Spowart G'],
#  ['Wilkins A', 'Andermann F', 'Ives J'],
#  ['Becker U', 'Fietzek PP', 'Furthmayr H', 'Timpl R'],
#  ['Reisfeld RA', 'Pellegrino MA', 'Dierich MP', 'Ferrone S'],
#  ['Stephens R', 'Traul K', 'Woolf D', 'Lowry G', 'Lelek J'],
#  ['Rosenthal AS', 'Blake JT', 'Lipsky PE'],
#  ['Hotz G'],
#  ['Komatsu T', 'Shinka S', 'Dohi Y', 'Amano T'],
#  ['Poulik MD', 'Reisfeld RA'],
#  ['Trenkner E', 'Riblet R'],
#  ['Sondel PM', 'Bach FH'],
#  ['Bevan MJ'],
#  ['Propper RH'],
#  ['Sloan B', 'Yocum C', 'Clem LW'],
#  ['Johnston MI', 'Stollar BD', 'Torrence PF', 'Witkop B'],
#  ['Cushing JE', 'Boraker DK'],
#  ['Inglis G', 'Bird GW', 'Mitchell AA', 'Milne GR', 'Wingham J'],
#  ['Hashim GA', 'Sharpe RD', 'Carvalho EF', 'Stevens LE'],
#  ['Heber-Katz E', 'Wilson DB'],
#  ['Heatley RV', 'Hughes LE', 'Morgan A', 'Okwonga W'],
#  ['Weiss RR',
#   'Macri JN',
#   'Elligers K',
#   'Princler GL',
#   'McIntire R',
#   'Waldman TA'],
#  ['Miyagawa N', 'Ashizawa T', 'Kashiba S', 'Miyagawa S', 'Fujio H'],
#  ['Laurant C', 'de Lauzon SD', 'Cittanova N', 'Nunez E', 'Jayle MF'],
#  ['García Flores RF', 'Ita Cruz RA'],
#  ['Tycko DH', 'Anbalagan S', 'Liu HC', 'Ornstein L'],
#  ['Regan D'],
#  ['Bach ML', 'Lindahl KF', 'Poulik MD'],
#  ['Sailer R', 'Katoh E', 'Drüneklee D', 'Kovaciecek S', 'Berger M'],
#  ['Ada GL', 'Blanden RV'],
#  ['Roelants GE'],
#  ['Fisherman EW', 'Cohen GN'],
#  ['Leevy CM', 'Chen T', 'Luisada-Opper A', 'Kanagasundaram N', 'Zetterman R'],
#  ['Janeway CA Jr'],
#  ['Dennert G'],
#  ['Vater J', 'Kleinkauf H'],
#  ['Ehrenberg BL', 'Penry JK'],
#  ['Kano S', 'Bloom BR', 'Shreffler DC'],
#  ['Sondel PM', 'Bach FH'],
#  ['Frist S', 'Wenz B'],
#  ['Palay SL', 'Chan-Palay V'],
#  ['Gustavsson I', 'Hageltorn M', 'Zech L'],
#  ['Tauber JW'],
#  ['Mäkelä O', 'Koskimies S', 'Karjalainen K'],
#  ['Beenken O', 'Häntzschel H', 'Birkenmeier G', 'Pietruschka WD', 'Otto W'],
#  ['Pearson J', 'Milstoc M', 'Harris J', 'Budzilovich G', 'Feigin I'],
#  ['Coltman CA Jr', 'Panettiere F', 'Carmel R'],
#  ['Chen HC',
#   'Hodgen GD',
#   'Matsuura S',
#   'Lin LJ',
#   'Gross E',
#   'Reichert LE Jr',
#   'Birken S',
#   'Canfield RE',
#   'Ross GT'],
#  ['Borel Y'],
#  ['Keinert K'],
#  ['Fougereau M',
#   'Schiff C',
#   'Mathieu C',
#   'de Préval C',
#   'Bourgois A',
#   'Moulin A',
#   'Rocca-Serra J'],
#  ['Maniatis T', 'Kee SG', 'Efstratiadis A', 'Kafatos FC'],
#  ['Rosenthal AS', 'Shevach EM'],
#  ['Ostberg L', 'Lindblom JB', 'Peterson PA'],
#  ['Pecht I'],
#  ['Soter NA', 'Austen KF'],
#  ['Sundermann A', 'Fink R'],
#  ['Truffa-Bachi P'],
#  ['Gotman J', 'Gloor P'],
#  ['Schreiber RD', 'Götze O', 'Müller-Eberhard HJ'],
#  ['Rehn TG', 'Inman JK', 'Shearer GM'],
#  ['Zinkernagel RM'],
#  ['Cooper NR', 'Jensen FC', 'Welsh RM Jr', 'Oldstone MB'],
#  ['Fernandez-Madrid F', 'Mattioli M'],
#  ['Warr GW', 'Marchalonis JJ'],
#  ['Kravis TC', 'Ahmed A', 'Brown TE', 'Fulmer JD', 'Crystal RG'],
#  ['Katz DH', 'Chiorazzi N', 'McDonald J', 'Katz LR'],
#  ['Thomas DW', 'Shevach EM'],
#  ['Hackett PH', 'Rennie D', 'Levine HD'],
#  ['Mansell PW', 'DiLuzio NR', 'McNamee R', 'Rowden G', 'Proctor JW'],
#  ['Janeway CA', 'Maurer PH', 'Dailey MO', 'Inman JK'],
#  ['Janeway CA', 'Paul WE'],
#  ['Kirchner M', 'Hofmann A'],
#  ['Rowell FJ', 'Paxton JW'],
#  ['Schwartz RH', 'Horton CL', 'Paul WE'],
#  ['Islam AK'],
#  ['Tanaka N', 'Ikeda H', 'Ueno T', 'Takahashi M', 'Imasato Y'],
#  ['Perryman KM', 'Linsley DB'],
#  ['Bodis-Wollner I'],
#  ['Spraker TE', 'Arnett DW'],
#  ['Boyd ES', 'Boyd EH', 'Brown LE'],
#  ['Stanislawski M', 'Mitard M'],
#  ['Stashenko PP', 'Schlossman SF'],
#  ['Schoub BD', 'Lecatsas G', 'Prozesky OW'],
#  ['Müller M'],
#  ['Davidson WF', 'Pang T', 'Blanden RV', 'Doherty PC'],
#  ['Brown RD', 'Armentrout RW'],
#  ['Charreire J', 'Carnaud C'],
#  ['Harter MR', 'Deaton FK', 'Odom JV'],
#  ['Lake P', 'Mitchison NA'],
#  ['Igarashi T', 'Okada M', 'Kishimoto T', 'Yamamura Y'],
#  ['Zinkernagel RM',
#   'Althage A',
#   'Adler B',
#   'Blanden RV',
#   'Davidson WF',
#   'Kees U',
#   'Dunlop MB',
#   'Shreffler DC'],
#  ['Billings P', 'Burakoff S', 'Dorf ME', 'Benacerraf B'],
#  ['Wolf JE', 'Faanes RB', 'Choi YS'],
#  ['Weiss DW'],
#  ['Chik L', 'Sokol RJ', 'Rosen MG'],
#  ['Hiramoto RN', 'Ghanta VK'],
#  ['Berry PR', 'Wallis WE'],
#  ['Thomas DW', 'Shevach EM'],
#  ['Marchalonis JJ'],
#  ['Albrechtsen D', 'Solheim BG', 'Thorsby E'],
#  ['Fenwick PB', 'Turner C'],
#  ['Lees O'],
#  ['Carnaud C', 'Fadaï-Ghotbi M', 'Lesavre P', 'Bach JF'],
#  ['Elliott BE', 'Nagy Z', 'Nabholz M', 'Pernis B'],
#  ['Tamoto K', 'Koyama J'],
#  ['Jokipii L', 'Jokipii AM'],
#  ['Gordon RD', 'Samelson LE', 'Simpson E'],
#  ['Grayhack JT', 'Wendel EF', 'Lee C', 'Oliver L', 'Cohen E'],
#  ['Brondz BD'],
#  ['Koepke JA'],
#  ['Lecas JC'],
#  ['Surolia A', 'Bachhawat BK'],
#  ['Schrader JW', 'Henning R', 'Milner RJ', 'Edelman GM'],
#  ['Howard JG', 'Moreno C', 'Hale C', 'Vicari G'],
#  ['Darzynkiewicz Z', 'Traganos F', 'Sharpless T', 'Melamed MR'],
#  ['Kaplow LS'],
#  ['Blanden RV', 'McKenzie IF', 'Kees U', 'Melvold RW', 'Kohn HI'],
#  ['Hayden MR', 'Vinik AI', 'Paul M', 'Beighton P'],
#  ['Caul EO', 'Ashley CR', 'Egglestone SI'],
#  ['Ennis FA', 'Martin WJ', 'Verbonitz MW', 'Butchko GM'],
#  ['Zighelboim J', 'Bick A', 'Durantez A'],
#  ['Benn PA'],
#  ['Rüde E', 'Günther E', 'Meyer-Delius M', 'Liehl E'],
#  ['Leveson SH', 'Howell JH', 'Holyoke ED', 'Goldrosen MH'],
#  ['Preece MA', 'Kearney PJ', 'Marshall WC'],
#  ['Coutinho A', 'Meo T', 'Watanabe T'],
#  ['Fiskin AM'],
#  ['Bhatnagar R', 'Johnson GR', 'Christian RG'],
#  ['Perine PL',
#   'Thornsberry C',
#   'Schalla W',
#   'Biddle J',
#   'Siegel MS',
#   'Wong KH',
#   'Thompson SE'],
#  ['Mekler LB'],
#  ['Brown KN'],
#  ['Brownlie BE'],
#  ['Keck K'],
#  ['Rosenthal AS', 'Barcinski MA', 'Rosenwasser LJ'],
#  ['Savage JR'],
#  ['Oldstone MB', 'Wilson CB', 'Perrin LH', 'Norris FH Jr'],
#  ['Marchalonis JJ', 'Bucana C', 'Hoyer L', 'Warr GW', 'Hanna MG Jr'],
#  ['Andrews EJ Jr'],
#  ['Holoye PY', 'Luna MA', 'MacKay B', 'Bedrossian CW'],
#  ['Gotman J', 'Gloor P', 'Schaul N'],
#  ['Pawlita M', 'Braun DG'],
#  ['Loch EG', 'Gaca A', 'Wessels G'],
#  ['Drew SI', 'Billing R', 'Bergh OJ', 'Terasaki PI'],
#  ['Matsuura S', 'Chen HC', 'Hodgen GD'],
#  ['Binz H'],
#  ['Price PG', 'Fisher AW'],
#  ['Snell GD'],
#  ['Hofmann R', 'Straube W', 'Klausch B'],
#  ['Ekwo EE'],
#  ['Takasugi J', 'Koide Y', 'Takasugi M'],
#  ['Peck AB', 'Murgita RA', 'Wigzell H'],
#  ['Westall FC'],
#  ['Hothem AL', 'Thomas CG Jr', 'Van Wyk JJ'],
#  ['Wright CB', 'Hiratzka LF', 'Crossland S', 'Isner J', 'Snow JA'],
#  ['Blanden RV', 'Ada GL'],
#  ['Klareskog L', 'Trägårdh L', 'Lindblom JB', 'Peterson PA'],
#  ['Carpel EF'],
#  ['Binnie CD',
#   'Batchelor BG',
#   'Bowring PA',
#   'Darby CE',
#   'Herbert L',
#   'Lloyd DS',
#   'Smith DM',
#   'Smith GF',
#   'Smith M'],
#  ['Rosenwasser LJ', 'Rosenthal AS'],
#  ['Arnon SS', 'Midura TF', 'Damus K', 'Wood RM', 'Chin J'],
#  ['Visch AH'],
#  ['Engberts J'],
#  ['Blanden RV', 'Pang T'],
#  ['Ferro AM', 'Minaga T', 'Piper WN', 'Kun E'],
#  ['Duwaer AL', 'Spekreijse H'],
#  ['Holder GE'],
#  ['Chisholm PM', 'Ford WL'],
#  ['Zaia JA', 'Leary PL', 'Levin MJ'],
#  ['Shaw S', 'Nelson DL', 'Shearer GM'],
#  ['Bennink JR', 'Doherty PC'],
#  ['Sunder-Plassmann P'],
#  ['Meesters-Timmermans S'],
#  ['Blumhardt LD', 'Barrett G', 'Halliday AM', 'Kriss A'],
#  ['Blanden RV', 'Kees U'],
#  ['Wallis WE', 'Willoughby E', 'Baker P'],
#  ['Braak H'],
#  ['Lake P', 'Douglas TC'],
#  ['Emmrich F', 'Ambrosius H'],
#  ['Bergholtz BO', 'Thorsby E'],
#  ['Tilney NL', 'Notis-McConarty J', 'Strom TB'],
#  ['Vera RS', 'Blume WT'],
#  ['Chakraborty T', 'Hansen J', 'Schazchneider B', 'Ristow H'],
#  ['Accolla RS', 'Celada F'],
#  ['Allegretti N'],
#  ['Brodersen I', 'Frentz G', 'Thomsen K'],
#  ['Scibienski RJ', 'Klingmann V', 'Leung C', 'Thompson K', 'Benjamini E'],
#  ['Schwartz RH', 'Solinger AM', 'Ultee M', 'Margoliash E'],
#  ['Rosenthal AS',
#   'Rosenwasser LJ',
#   'Baskin BL',
#   'Schroer J',
#   'Thomas JW',
#   'Blake JT'],
#  ['Beange H'],
#  ['Rosenwasser LJ', 'Rosenthal AS'],
#  ['Tosi R', 'Tanigaki N', 'Centis D', 'Ferrara GB', 'Pressman D'],
#  ['Biddison WE', 'Hansen TH', 'Levy RB', 'Doherty PC'],
#  ['Tomassini J', 'Roychoudhury R', 'Wu R', 'Roberts RJ'],
#  ['Bachorik PS', 'Kwiterovich PO', 'Cooke JC'],
#  ['Hetzelberger D', 'Eichmann K'],
#  ['Duffy RJ', 'McEwen WJ'],
#  ['Kabat EA'],
#  ['Robert M', 'Vincent C', 'Brochier J', 'Revillard JP'],
#  ['Cooper TB', 'MacLean WA', 'Waldo AL'],
#  ['Zarling DA', 'Keshet I', 'Watson A', 'Bach FH'],
#  ['Sandoz PA', 'Meier E'],
#  ['de Gaetani CF', 'Trentini GP'],
#  ['Harris JS', 'Randerath K'],
#  ['Subbarao B', 'Mosier DE', 'Ahmed A', 'Mond JJ', 'Scher I', 'Paul WE'],
#  ['Pool RR Jr'],
#  ['Hubelbank M', 'Feldman CL'],
#  ['Kinias P', 'Norusis M', 'Fozzard HA'],
#  ['Binz H', 'Wigzell H'],
#  ['Raff MC'],
#  ['Naeim F',
#   'Keesey JC',
#   'Herrmann C Jr',
#   'Lindstrom J',
#   'Zeller E',
#   'Walford RL'],
#  ['Rieber M', 'Rieber MS'],
#  ['Jeffreys DA', 'Smith AT'],
#  ['Fesseler A'],
#  ['Samson-Dollfus D', 'Goldberg P'],
#  ['Taylor G', 'Kumar S', 'Brenchley P', 'Wilson P', 'Costello B', 'Shaw GH'],
#  ['Rieber M', 'Rieber M', 'Alonso M'],
#  ['Fisher LJ'],
#  ['Höffken H', 'Otto K', 'Soost HJ'],
#  ['Eason PJ', 'Tucker JH'],
#  ['Habbersett MC', 'Shapiro M', 'Bunnag B', 'Nishiya I', 'Herman C'],
#  ['Al I', 'Ploem JS'],
#  ['Zahniser DJ', 'Oud PS', 'Raaijmakers MC', 'Vooys GP', 'Van de Walle RT'],
#  ['Bauer HW', 'Hasselblatt I', 'Husfeldt KJ', 'Bohn H'],
#  ['Muchmore AV', 'Decker JM', 'Blaese RM'],
#  ['Delovitch TL', 'Sohn U'],
#  ['Biddison WE', 'Shaw S'],
#  ['Delovitch TL', 'Sohn U'],
#  ['Neetens A', 'Hendrata Y', 'van Rompaey J'],
#  ['Buckell NA', 'Lennard-Jones JE'],
#  ['Flaherty L', 'Zimmerman D'],
#  ['Atassi MZ'],
#  ['Parry-Jones NO', 'Fenwick P'],
#  ['Gotman J', 'Ives JR', 'Gloor P'],
#  ['Binnie CD',
#   'Batchelor BG',
#   'Gainsborough AJ',
#   'Lloyd DS',
#   'Smith DM',
#   'Smith GF'],
#  ['Nüssner J'],
#  ['Murthy IS', 'Rangaraj MR'],
#  ['Ahmann GB', 'Nadler PI', 'Birnkrant A', 'Hodes RJ'],
#  ['Catalona WJ', 'Vaitukaitis JL', 'Fair WR'],
#  ['Teale JM', 'Mackay IR'],
#  ['Brondz BD', 'Drizlikh GI'],
#  ['Wank R', 'Schendel DJ', 'Blanco ME', 'Dupont B'],
#  ['Clement LT', 'Kask AM', 'Schwartz BD', 'Shevach EM'],
#  ['Décary F',
#   'Verheugt FW',
#   'van Helden-Henningheim L',
#   'von Riesz E',
#   'Schreuder-van Gelder R',
#   'von dem Borne AE',
#   'Engelfriet CP'],
#  ['Rosenthal AS'],
#  ['Beilby JO', 'Horne CH', 'Milne GD', 'Parkinson C'],
#  ['Jensen PJ', 'Koren HS'],
#  ['Rosenwasser LJ', 'Rosenthal AS'],
#  ['Kumar SP', 'Yans J', 'Kwatra M'],
#  ['Binz H'],
#  [],
#  ['Hösli P', 'Vogt E'],
#  ['Halbhuber KJ',
#   'Feuerstein H',
#   'Fröber R',
#   'Stibenz D',
#   'Linss W',
#   'Geyer G'],
#  ['Bosman FT', 'Nieuwenhuijzen Kruseman AC'],
#  ['Smith AM', 'Miller JS', 'Whitehead DS'],
#  ['Sidorova OA'],
#  ['Koriat A', 'Levy I'],
#  ['Remschmidt H'],
#  ['Neumann BW', 'Grosdanoff P'],
#  ['Schreuder I', 'Nagtegaal-Bos A'],
#  ['Helders PJ'],
#  ['Mitsuyasu RT', 'Gale RP'],
#  ['Wilke H', 'Harms D'],
#  ['Epstein CM'],
#  ['Gevins AS',
#   'Zeitlin GM',
#   'Yingling CD',
#   'Doyle JC',
#   'Dedon MF',
#   'Schaffer RE',
#   'Roumasset JT',
#   'Yeager CL'],
#  ['Gevins AS', 'Zeitlin GM', 'Doyle JC', 'Schaffer RE', 'Callaway E'],
#  ['Bak MJ', 'Loeb GE'],
#  ['Wieder KJ', 'Palczuk NC', 'van Es T', 'Davis FF'],
#  ['Okudaira K',
#   'Nakai H',
#   'Hayakawa T',
#   'Kashiwado T',
#   'Tanimoto K',
#   'Horiuchi Y',
#   'Juji T'],
#  ['Werdelin O', 'Shevach EM'],
#  ['Goldberg MI', 'Kennedy SF'],
#  ['Solinger AM', 'Ultee ME', 'Margoliash E', 'Schwartz RH'],
#  ['Carnaud C', 'Errasti P', 'van der Gaag R'],
#  ['Meyenburg M', 'Maassen V'],
#  ['Himeno K'],
#  ['Marmont AM',
#   'Santini G',
#   'Piaggio G',
#   'Raffo MR',
#   'Damasio E',
#   'Carella M',
#   'Rossi E',
#   'Giordano D',
#   'Cerri R',
#   'Van Lint MT',
#   'Vimercati R',
#   'Risso M',
#   'Podesta M',
#   'Bacigalupo A'],
#  ['Cumsky M', 'Zusman DR'],
#  ['Fathman CG', 'Hengartner H'],
#  ['McGadey J'],
#  ['Louis J', 'Moedder E', 'Behin R', 'Engers H'],
#  ['Meienberg O', 'Kutak L', 'Smolenski C', 'Ludin HP'],
#  ['Krajczár G', 'Szokol M'],
#  ['Smith FI', 'Mottram PL', 'Miller JF'],
#  ['Watson A', 'Zarling DA', 'Bach FH'],
#  ['Sarnat HB', 'deMello DE', 'Siddiqui SY'],
#  ['Schmid K', 'Ritschewald S', 'Schmitt R'],
#  ['Thomas JW', 'Schroer J', 'Yokomuro K', 'Blake JT', 'Rosenthal AS'],
#  ['Ono K',
#   'Ogasawara M',
#   'Ohashi A',
#   'Matsukage A',
#   'Takahashi T',
#   'Nakayama C',
#   'Saneyoshi M'],
#  ['Süss J'],
#  ['Lesevre N', 'Joseph JP'],
#  ['Jones JS'],
#  ['Barcinski MA', 'Rosenthal AS'],
#  ['Bahl CP', 'Wu R', 'Narang S'],
#  ['Laing FC', 'London LA', 'Filly RA'],
#  ['Knudsen KA', 'Horwitz AF'],
#  ['Spiegelman GB', 'Whiteley HR'],
#  ['Balthazar EJ', 'Schechter LS'],
#  ['Aliabadi P', 'Shafiepoor H'],
#  ['Isaacs I'],
#  ['Al-Bahrani Z',
#   'Al-Saleem T',
#   'Al-Mondhiry H',
#   'Bakir F',
#   'Yahia H',
#   'Taha I',
#   'King J'],
#  ['Kinney FC'],
#  ['Ricciardi ID', 'Pearson AD', 'Suckling WG', 'Klein C'],
#  ['Meyhack B', 'Pace B', 'Uhlenbeck OC', 'Pace NR'],
#  ['Cho KJ', 'Martel W'],
#  ['Gray LP'],
#  ['Houwing CJ', 'Jaspars EM'],
#  ['Chany-Fournier F', 'Pauloin A', 'Cerutti I', 'Chany C'],
#  ['Kersten H', 'Raettig R', 'Weissenbach J', 'Dirheimer G'],
#  ['Kobayashi K',
#   'Kameda S',
#   'Sugimoto T',
#   'Suzuki K',
#   'Nishimura K',
#   'Kato Y',
#   'Hattori N',
#   'Nakaya Y',
#   'Takase S',
#   'Takada A',
#   'Takeuchi J'],
#  ['Booth DR'],
#  ['Sack G', 'Feudell P'],
#  ['Hamilton CR'],
#  ['Prior PF', 'Maynard DE', 'Brierley JB'],
#  ['Siebert GR', 'Harris JF', 'Gefter ML'],
#  ['Thompson DM', 'Pegelow CH', 'Singsen BH', 'Powars DR', 'Hanson V'],
#  ['Rosenbloom AL', 'Malone JI'],
#  ['Kyle RA', 'Greipp PR'],
#  ['Weinstein H', 'Green JP', 'Osman R', 'Edwards WD'],
#  ['Agha A',
#   'Sakati NO',
#   'Higginbottom MC',
#   'Jones KL Jr',
#   'Bay C',
#   'Nyhan WL'],
#  ['Berzofsky JA', 'Pisetsky DS', 'Schwartz RH', 'Schechter AN', 'Sachs DH'],
#  ['Mozes E'],
#  ['Bayer AS', 'Yoshikawa TT', 'Nolan F', 'Shibata S', 'Guze LB'],
#  ['Binet JP', 'Losay J', 'Leriche H', 'Conso JF', 'Bruniaux J'],
#  ['Röhrborn W', 'von Figura K'],
#  ['Jacoby GA',
#   'Weiss R',
#   'Korfhagen TR',
#   'Krishnapillai V',
#   'Jacob AE',
#   'Hedges RW'],
#  ['Kubinski ZO', 'Kubinski H'],
#  ['Geckeler W', 'Faversham J', 'Cohn M'],
#  ['Kappler JW', 'Marrack P'],
#  ['Dunn WJ 3rd', 'Wold S'],
#  ['Pierre RV'],
#  ['Meyhack B', 'Pace NR'],
#  ['Horn E'],
#  ['Bobrova TS', 'Kriukova IN', 'Voronina AN', 'Bassalyk LS'],
#  ['Petrides M', 'Iversen SD'],
#  ['Montreuil J', 'Fournet B', 'Spik G', 'Strecker G'],
#  ['Klein I'],
#  ['Fraser TH', 'Bruce BJ'],
#  ['Kaufman SL', 'White RI Jr', 'Harrington DP', 'Barth KH', 'Siegelman SS'],
#  ['Scheuler W', 'Ulrich G'],
#  ['Miller LH', 'Aikawa M', 'Johnson JG', 'Shiroishi T'],
#  ['Mollison PL'],
#  ['Werner B', 'Schumpelick V'],
#  ['Cigtay OS', 'Mascatello VJ'],
#  ['Kane JF', 'Wainscott VJ', 'Hurt MA'],
#  ['Casselman ES', 'Mandell GA'],
#  ['Conrad MR', 'Bregman R', 'Kilman WJ'],
#  ['Wilkins AJ', 'Darby CE', 'Binnie CD'],
#  ['Ewert JP', 'Arend B', 'Becker V', 'Borchers HW'],
#  ['Drew SI'],
#  ['Yoshimura Y', 'Gabka J'],
#  ['Biener K'],
#  ['Bolster B', 'Crowne DP'],
#  ['Martin JE', 'Moskowitz M', 'Milbrath JR'],
#  ['Childress MH', 'Cho KJ', 'Newlin N', 'Martel W'],
#  ['Weiskrantz L'],
#  ['Forman HR', 'Kotler MN', 'Segal BL', 'Parry WR'],
#  ['Gratsianskiĭ NA',
#   'Karpov IuA',
#   'Iagubova AS',
#   'Ostrogorskiĭ IU',
#   'Ruda MIa'],
#  ['Newsome HH Jr'],
#  ['Harwerth RS', 'Boltz RL'],
#  ['Jensen NE'],
#  ['Seacord L', 'Gross CG', 'Mishkin M'],
#  ['Jürgens U', 'Pratt R'],
#  ['Wenger NK', 'Felner JM'],
#  ['Katz DH'],
#  ['Katz DH'],
#  ['Singer A', 'Hathcock KS', 'Hodes RJ'],
#  ['Bajaj JS', 'Khardori R', 'Deo MG', 'Bansal DD'],
#  ['Robertson M'],
#  ['Walter P', 'Jackson RC', 'Marcus MM', 'Lingappa VR', 'Blobel G'],
#  ['Han BK', 'Dunbar JS', 'Striker TW'],
#  ['Felson B'],
#  ['Scher AT'],
#  ['Pinto RS', 'Handel SF', 'Sadhu VK'],
#  ['Chisolm JJ Jr', 'Barltrop D'],
#  ['Fisher ER', 'Palekar AS', 'Paulson JD', 'Golinger R'],
#  ['Young RA', 'Steitz JA'],
#  ['Byrd RB', 'Fisk DE', 'Roethe RA', 'Glover JN', 'Wooster LD', 'Wilder NJ'],
#  ['Grüsser OJ', 'Pause M', 'Schreiter U'],
#  ['Charpentier B', 'Carnaud C', 'Bach JF'],
#  ['Shortman K', 'Golstein P'],
#  ['Berg E', 'Fischer R', 'Schaake C'],
#  ['Gross CG', 'Bender DB', 'Gerstein GL'],
#  ['Schrier AM', 'Povar ML', 'Schrier JE'],
#  ['Rao DN', 'Rudikoff S', 'Krutzsch H', 'Potter M'],
#  ['Klein PB', 'Weilemann WA', 'Schroeder HE'],
#  ['Niki H', 'Watanabe M'],
#  ['Khoury EL',
#   'Ritacco V',
#   'Cossio PM',
#   'Laguens RP',
#   'Szarfman A',
#   'Diez C',
#   'Arana RM'],
#  ['Thomas DW', 'Meltz SK', 'Wilner GD'],
#  ['Catlin FI'],
#  ['Rees DA', 'Badley RA', 'Lloyd CW', 'Thom D', 'Smith CG'],
#  ['Katz DH'],
#  ['Walz FG Jr', 'Osterman HL', 'Libertin C'],
#  ['Rogers JG', 'Geho WB'],
#  ['Gross CG'],
#  ['Butter CM'],
#  ['De Valois KK', 'De Valois RL', 'Yund EW'],
#  ['van Rij AM', 'McKenzie JM', 'Robinson MF', 'Thomson CD'],
#  ['Williamson VM', 'Doi RH'],
#  ['Schreiber W'],
#  ['Sasaki CT', 'Koss N'],
#  ['Ullrich K', 'Basner R', 'Gieselmann V', 'Von Figura K'],
#  ['Ewert JP', 'Burghagen H'],
#  ['Salem BI',
#   'Terasawa M',
#   'Mathur VS',
#   'Garcia E',
#   'de Castro CM',
#   'Hall RJ'],
#  ['Haehn KD'],
#  ['Hippius H'],
#  ['Strome M'],
#  ['Brodsky WA',
#   'Sadoff JC',
#   'Durham JH',
#   'Ehrenspeck G',
#   'Schachner M',
#   'Iglewski BH'],
#  ['Tan RJ', 'Lim VK'],
#  ['Hearn JP'],
#  ['Meier M', 'Steppuhn U', 'Rück W'],
#  ['Ziegler K', 'Unanue ER'],
#  ['Weinberger JZ', 'Benacerraf B', 'Dorf ME'],
#  ['Distler J', 'Hieber V', 'Sahagian G', 'Schmickel R', 'Jourdian GW'],
#  ['Wu TT', 'Kabat EA', 'Bilofsky H'],
#  ['Kemp DJ', 'Cory S', 'Adams JM'],
#  ['Reisberg BE'],
#  ['Mair WG', 'Warrington EK', 'Weiskrantz L'],
#  ['Gazzaniga MS', 'Volpe BT', 'Smylie CS', 'Wilson DH', 'LeDoux JE'],
#  ['Rosenfeld SA', 'Van Hoesen GW'],
#  ['Hewett TD', 'Ettlinger G'],
#  ['Elsas PP', 'Barcinski MA'],
#  ['Enna SJ'],
#  ['Yu VY', 'James B', 'Hendry P', 'MacMahon RA'],
#  ['Simmonds HA'],
#  ['Capo C', 'Benoliel AM', 'Bongrand P', 'Depieds R'],
#  ['Stötter H', 'Imm A', 'Meyer-Delius M', 'Rüde E'],
#  ['Devine JV', 'Burke MW', 'Rohack JJ'],
#  ['Heintel H', 'Faust U', 'Faust C'],
#  ['Karle H', 'Hansen NE', 'Malmquist J', 'Karle AK', 'Larsson I'],
#  ['Cusick CF'],
#  ['Tarsitano JJ', 'Gossman JR Jr'],
#  ['Iwai E', 'Osawa Y', 'Umitsu Y'],
#  ['Grill W'],
#  ['Taylor DW', 'Siddiqui WA'],
#  ['Snigurowicz J', 'Powiertowska-Rezmer M', 'Rostkowska J'],
#  ['Silano V'],
#  ['Kiefer G'],
#  ['Sternberg E'],
#  ['Wartmann B', 'Söll A'],
#  ['Wässer S', 'Theile H', 'Graustein I', 'Bührdel P'],
#  ['Neumann HJ', 'Dieckmann O', 'Andrä A'],
#  ['Ritzmann SE', 'Loukas D', 'Sakai H', 'Daniels JC', 'Levin WC'],
#  ['Gallily R'],
#  ['Dagnini G'],
#  ['Strunk BL', 'Guss SB', 'Hicks RE', 'Kotler MN'],
#  ['Gerbase-DeLima M', 'Meredith P', 'Walford RL'],
#  ['Pipberger HV'],
#  ['Ficat P', 'Ficat C', 'Bailleux A'],
#  ['Thompson JE', 'Hollier LH', 'Patman RD', 'Persson AV'],
#  ['Perkins DD'],
#  ['Taylor PV', 'Hancock KW'],
#  ['Cooper JW Jr'],
#  ['Benchimol A', 'Desser KB', 'Hastreiter AR'],
#  ['Shirey EK', 'Hawk WA'],
#  ['Lipmann F'],
#  ['Tipton W Jr', "D'Ambrosia RD", 'Corkill G'],
#  ['Popp RL', 'Brown OR', 'Harrison DC'],
#  ['Cornfield J', 'Pipberger HV', 'Dunn RA'],
#  ['Tschubel K', 'Helpap B', 'Boldt I', 'Bastian P'],
#  ['Soulillou JP', 'Carpenter CB', 'Lundin AP', 'Strom TB'],
#  ['Leiber B'],
#  ['Wagner H', 'Trostmann H', 'Pfizenmaier K', 'Röllinghoff M'],
#  ['Dodd B'],
#  ['Ozato K', 'Ebert JD'],
#  ['Kliuev II', 'Piksin IN', 'Bobkov VF', 'Kliuev VI'],
#  ['Morris DC', 'Felner JM', 'Schlant RC', 'Franch RH'],
#  ['Jinno K'],
#  ['Maruta T', 'Swanson DW', 'Swenson WM'],
#  ['Rovner AJ', 'Westcott JL'],
#  ['Lalani AV', 'Lee SJ'],
#  ['Farooqui MO', 'Bazzoli JM'],
#  ['Melvill RL'],
#  ['Petrozzi JW', 'Shore RN'],
#  ['Berman M', 'Puryear K', 'Argyris BF'],
#  ['Simonson E'],
#  ['Gache C', 'Rossi B', 'Lazdunski M'],
#  ['Tomoike H', 'Kawaguchi K', 'Takeshita A', 'Hirata T', 'Nakamura M'],
#  ['Whittingham S', 'Mackey IR'],
#  ['Knörr K', 'Jonatha WD', 'Tettenborn U'],
#  ['Ferrone S', 'Pellegrino MA', 'Cooper NR'],
#  ['Snell GD'],
#  ['Weedon AP'],
#  ['Abdel-Monem M', 'Hoffmann-Berling H'],
#  ['Terris S', 'Steiner DF'],
#  ['Fitch FW', 'Ramseier H'],
#  ['Asantila T', 'Toivanen P'],
#  ['Zingirian M'],
#  ['Hauser H', 'Sacoun A'],
#  ['Haid T', 'Wigand ME'],
#  ['Jovin TM'],
#  ['Reichenberger M', 'Ebke M', 'Patiri C'],
#  ['Uno M', 'Katahira S', 'Itô M', 'Huziwara T'],
#  ['Friedrich M', 'Weskamp P'],
#  ['von Ilberg C', 'Kleinmann H', 'Arnold W'],
#  ['von Zimmermann H'],
#  ['Berger H', 'Pardoll D'],
#  ['Dieroff HG'],
#  ['Robinson HB', 'Smith GW'],
#  ['Kiefer G', 'Sandritter W'],
#  ['Friedman J', 'Razin A'],
#  ['Berkutov AN', 'Deriabin II', 'Zakurdaev VE'],
#  ['Yunis EJ', 'Dupont B', 'Hansen J'],
#  ['Richardson SA'],
#  ['Rittner C'],
#  ['Habermann M', 'Windorfer K', 'Petzel H'],
#  ['Kuss VE Goebel R'],
#  ['Bach FH'],
#  ['Lessof MH'],
#  ['Brack C', 'Eberle H', 'Bickle TA', 'Yuan R'],
#  ['Smith JB', 'Knowlton RP', 'Koons LS'],
#  ['Fujita K', 'Maeda K', 'Takasugi T', 'Tsukano Y', 'Tanaka N'],
#  ['Romano MD'],
#  ['Bergmann VI', 'Rebohle E', 'Wallenstein G', 'Gemeinhardt H', 'Thrümer H'],
#  ['Chang JH', 'Kiesewetter WB'],
#  ['Clayton JM', 'Russell HE', 'Hartford CE', 'Boyd WC', 'Barnes RW'],
#  ['Tsao TF', 'Marzluf GA'],
#  ['Lebowitz RL', 'Griscom NT'],
#  ['Dietrich CP', 'Sampaio LO', 'Toledo OM', 'Cássaro CM'],
#  ['Cocks P', 'Powles RL', 'Chapuis B', 'Alexander P'],
#  ['Wegener OH'],
#  ['Robinson HB', 'Donahoo JS'],
#  ['Coulson AS',
#   'Zeitman VH',
#   'Cohn RB',
#   'Dong E',
#   'Griepp RB',
#   'Stinson EB',
#   'Shumway NE'],
#  ['Abel H', 'Zywietz C', 'Klusmeir S'],
#  ['Mehta J', 'Tuna N', 'Moller JH', 'Desnick RJ'],
#  ['Peck AB', 'Janeway CA Jr', 'Wigzell H'],
#  ['Dennert G', 'Hyman R'],
#  ['Hayward AR', 'Soothill JF'],
#  ['Zaĭtsev VV'],
#  ['Gorski J', 'Schubert J'],
#  ['Toledo OM', 'Dietrich CP'],
#  ['Ikram H', 'Drysdale P', 'Bones PJ', 'Chan W'],
#  ['Lonshakov IuI',
#   'Terekhova NIa',
#   'Guzenko AV',
#   'Bolotina IuL',
#   'Khotskaia OV'],
#  ['Jones DB'],
#  ['Bach FH', 'Bach ML', 'Kuperman OJ', 'Sollinger HW', 'Sondel PM'],
#  ['Weissleder H', 'Kiefer H'],
#  ['Yeh BP', 'Young HF', 'Schatzki PF', 'Bear ES'],
#  ['Nikolaeva DV'],
#  ['Loskutova GP', 'Vesnin AG'],
#  ['Meiler J'],
#  ['Eshniiazov NE', 'Kabulov MK'],
#  ['Alekhnovich MV'],
#  ['Ribaric V'],
#  ['Fowler AK', 'Twardzik DR', 'Reed CD', 'Weislow OS', 'Hellman A'],
#  ['Kessler M', 'Konrad E', 'Lissner J', 'Prechtel K'],
#  ['Biersack HJ', 'Thelen M', 'Knopp R', 'Breuel HP', 'Winkler C'],
#  ['Weksler ME', 'Kozak R'],
#  ['Friedman J', 'Friedmann A', 'Razin A'],
#  ['Shah PM'],
#  ['Rossini AA', 'Like AA', 'Dulin WE', 'Cahill GF Jr'],
#  ['Reichelt HG', 'Pichlmayr R'],
#  ['Meiler J'],
#  ['Lilliehöök B', 'Blomgren H', 'Jacobsson H'],
#  ['Brondz BD'],
#  ['McCluskey RT', 'Hall CL', 'Colvin RB'],
#  ['del Castillo B', 'Alvarez-Builla J', 'Martinez-Honduvilla CJ'],
#  ['Krishchian EM', 'Asatrian DG'],
#  ['Derbes VJ'],
#  ['Rytter M', 'Haustein UF'],
#  ['Bearn AG'],
#  ['Molinski H'],
#  ['Loskutova GP'],
#  ['McDonald PT', 'Rich NM', 'Collins GJ Jr', 'Andersen CA', 'Kozloff L'],
#  ['Smith B', 'Phillips CJ'],
#  ['Niethard FU', 'Puhl W'],
#  ['Chen CH', 'Kawai C'],
#  ['Gula G', 'Chew C', 'Radley-Smith R', 'Yacoub M'],
#  ['Ikeda H', 'Toge T', 'Niimoto M', 'Hattori T'],
#  ['Piperno JR', 'Kallen RG', 'Alberta BM'],
#  ['Denburg JL'],
#  ['Mollitt DL', 'Ballantine TV', 'Grosfeld JL', 'Quinter P'],
#  ['Pavlov KA',
#   'Semiglazov VF',
#   'Chernomordikova MF',
#   'Sanchakova AV',
#   'Aleksandrova GI'],
#  ['Nechiporenko AZ', 'Bogdanovich FA', 'Nechiporenko NA'],
#  ['Kleinman PK', 'Brill PW', 'Whalen JP'],
#  ['Haskett J', 'Hollar WD'],
#  ['van der Harst-Oostveen CJ', 'van Vloten WA'],
#  ['Steuer W'],
#  ['Schendel DJ', 'Wank R', 'Dupont B'],
#  ['Marcinski A', 'Wermenski K', 'Wagner A'],
#  ['Stephen R', 'Amato S'],
#  ['Schumacher KA', 'Rittmeyer K'],
#  ['Lüning M', 'Stargardt A', 'Abet L'],
#  ['Bühner R', 'Gottschalk R'],
#  ['Kyaw TA', 'Nyunt T', 'Sundaresan TK', 'Tarizzo ML'],
#  ['Mans L', 'Cicchetti D', 'Sroufe LA'],
#  ['Lenaz G', 'Curatola G', 'Mazzanti L', 'Parenti-Castelli G'],
#  ['Das A', 'Merril C', 'Adhya S'],
#  ['Brecht G', 'Lackner K', 'Brecht T', 'Thurn P'],
#  ['Taylor GM', 'Fergusson WD', 'Harris R'],
#  ['Deonna T', 'Voumard C'],
#  ['McIntyre JA', 'Faulk WP'],
#  ['Chen CH', 'Nobuyoshi M', 'Kawai C'],
#  ['Selecki BR'],
#  ['Feuerbach S',
#   'Rupp N',
#   'Rossmann W',
#   'Heller HJ',
#   'Rothenberger G',
#   'Tauber R',
#   'Schmidt G'],
#  ['Wakabayashi S'],
#  ['Lutsky I', 'Toshner D'],
#  ['Meredith PJ', 'Walford RL'],
#  ['Tanaka S', 'Sakai A'],
#  ['Mally MB', 'Taylor RC', 'Callewaert DM'],
#  ['Badelon O', 'David H', 'Meyer L', 'Radault A', 'Zucman J'],
#  ['Strong DM',
#   'Ahmed A',
#   'Leapman SB',
#   'Gawith K',
#   'Goldman MH',
#   'Smith AH',
#   'Sell KW'],
#  ['Dalke P', 'Magill JM'],
#  ['Kuczmarski ER', 'Rosenbaum JL'],
#  ['Eloy R', 'Haffen K', 'Kedinger M', 'Grenier JF'],
#  ['Zier KS', 'Huber C', 'Braunsteiner H'],
#  ['Fenton KS', 'Yoshida RK', 'Maxwell JP', 'Kaufman MJ'],
#  ['Mastro AM', 'Krupa TA', 'Smith P'],
#  ['Stratford B'],
#  ['Levis WR', 'Dattner AM', 'Shaw JS'],
#  ['Mehrtens G'],
#  ['Landry DJ', 'Vanhoutte JJ', 'Raeside DE'],
#  ['McIntyre JA', 'Faulk WP'],
#  ['Myers RH', 'Falek A'],
#  ['Segal BL', 'Kotler MN', 'Iskandrian A', 'Herling IM'],
#  ['Sommer B', 'Heidenreich P', 'Vogt H', 'Klotz E'],
#  ['Houde R'],
#  ['Lebrec D', 'Capron JP', 'Dhumeaux D', 'Benhamou JP'],
#  ['Nagy ZA', 'Elliott BE'],
#  ['Granone AA', 'Faletti C', 'Gavazza M'],
#  ['de Crombrugghe B', 'Mudryj M', 'DiLauro R', 'Gottesman M'],
#  ['Devens B', 'Naor D', 'Kedar E'],
#  ['Köhler E'],
#  ['Morhenn V', 'Engleman E', 'Farber EM'],
#  ['Chibon P',
#   'Brugal G',
#   'Chassery JM',
#   'Bouttaz R',
#   'Adelh D',
#   'Garbay C',
#   'Giroud F'],
#  ['Arnott JL', 'Newell AF', 'Downton AC'],
#  ['Wehlage DF'],
#  ['Wehlage DF'],
#  ['Wehlage DF'],
#  ['DiChiro G', 'Axelbaum SP', 'Schellinger D', 'Twigg HL', 'Ledley RS'],
#  ['Stossel TP'],
#  ['Ryan DS', 'Feeney RE'],
#  ['Geme JW Jr',
#   'Yamauchi T',
#   'Eisenklam EJ',
#   'Noren GR',
#   'Aase JM',
#   'Jurmain RB',
#   'Henn RM',
#   'Gabel MC',
#   'Hollister AW',
#   'Paumier R'],
#  ['Costlow ME', 'Buschow RA', 'Richert NJ', 'McGuire WL'],
#  ['Ueda T', 'Terayama K', 'Kurihara K', 'Kobatake Y'],
#  ['Zollinger RM'],
#  ['Biemer JJ', 'McCammon RE'],
#  ['Lin MC', 'Wright DE', 'Hruby VJ', 'Rodbell M'],
#  ['Wilcox LC', 'Barnett WJ'],
#  ['Kozhevnikov AI', 'Iakhontov NE', "Pankst'ianov AI"],
#  ['Pliam MB', 'ReMine WH'],
#  ['Sherk HH'],
#  ['Dodd NJ'],
#  ['Dodd NJ'],
#  ['Lutwak L'],
#  ['Roberts JW', 'Carbon J'],
#  ['Chignell CF', 'Starkweather DK', 'Sinha BK'],
#  ['Alder LT', 'Adler FL'],
#  ['Wehling K', 'Arfmann HA', 'Standke KH', 'Wagner KG'],
#  ['Mäkinen J', 'Rapola J'],
#  ['Gopalakrishnan P', 'Miller JE', 'McLaughlin JS'],
#  ['Wainberg MA', 'Markson Y', 'Doljanski F', 'Weiss DW'],
#  ['Monif GR', 'Daly JW'],
#  ['Gibb W', 'Jeffery J'],
#  ['Ghatak NR'],
#  ['Kalter SS', 'Heberling RL'],
#  ['McKenna RW', 'Bloomfield CD', 'Dick F', 'Nesbit ME', 'Brunning RD'],
#  ['Alexander JK', 'Tyler B'],
#  ['Rose JK'],
#  ['Schwartz J', 'Elizan TS'],
#  ['Watson LP', 'Lee CM'],
#  ['Vorherr H'],
#  ['Goldstein IM', 'Roos D', 'Kaplan HB', 'Weissmann G'],
#  ['Garfin DE', 'Boyer HW', 'Goodman HM'],
#  ['Jard S', 'Bockaert J'],
#  ['Rabinovitch A', 'Gutzeit A', 'Kikuchi M', 'Cerasi E', 'Renold AE'],
#  ['Schaffner F'],
#  ['Collewijn H'],
#  ['Panitz N', 'Rieke E', 'Morr M', 'Wagner KG', 'Roesler G', 'Jastorff B'],
#  ['Zulqar-nain BJ'],
#  ['Barrington EJ'],
#  ['Meyer KK'],
#  ['Becker MA', 'Seegmiller JE'],
#  ['Hellman B', 'Sehlin J', 'Söderberg M', 'Täljedal IB'],
#  ['McClain EJ', 'Wissinger HA'],
#  ['Beecham CT'],
#  ['André JL', 'Afflalo G', 'Duprez A', 'Kifffer B', 'Neimann N'],
#  ['Poirier R', 'Locher C', 'Kleisbauer JP', 'Laval P'],
#  ['Marty R', 'Denney JD', 'McKamey MR', 'Rowley MJ'],
#  ['Miller EJ',
#   'Harris ED Jr',
#   'Chung E',
#   'Finch JE Jr',
#   'McCroskery PA',
#   'Butler WT'],
#  ['Uttley AM'],
#  ['Uttley AM'],
#  ['Hernandez FJ', 'Fernandez BB'],
#  ['Bleher EA'],
#  ['Perdrizet S', 'Clauzel AM', 'Hatton F', 'Chrétien J'],
#  ['Assmus H', 'Mischkowsky T', 'Kröger M'],
#  ['Harwood TR', 'Gracey DR', 'Yokoo H'],
#  ['Jensen PS'],
#  ['Ravin CE', 'Putman CE', 'McLoud TC'],
#  ['Neviaser RJ', 'Adams JP', 'May GI'],
#  ['Kaufmann G'],
#  ['Liarskaia TIa', 'Ketiladze ES', 'Poliakova TG'],
#  ['Levy J', 'Herchuelz A', 'Sener A', 'Malaisse WJ'],
#  ['Ada GI', 'Jackson DC', 'Blanden RV', 'Hla RT', 'Bowern NA'],
#  ['Rabinowitz JG', 'Siegle RL'],
#  ['Hudson TM', 'Caragol WJ', 'Kaye JJ'],
#  ['Platt MR', 'Parkey RW', 'Willerson JT', 'Bonte FJ', 'Shapiro W', 'Sugg WL'],
#  ['Vater J', 'Kleinkauf H'],
#  ['Cazenave JP',
#   'Reimers HJ',
#   'Kinlough-Rathbone RL',
#   'Packham MA',
#   'Mustard JF'],
#  ['Ohlsson K'],
#  ['Murphy WM'],
#  ['Hughes FA', 'Davis CS'],
#  ['Zeman GH', 'Rao GU', 'Doyle RJ'],
#  ['Goldstein DP'],
#  ['Gruss P', 'Sauer G'],
#  ['Proffitt MR', 'Hirsch MS', 'Ellis DA', 'Gheridian B', 'Black PH'],
#  ['Voorhees JJ', 'Duell EA', 'Chambers DA', 'Marcelo CL'],
#  ['Koivuniemi A', 'Tyrkkö J'],
#  ['Bogoch S'],
#  ['Rein A', 'Kashmiri SV', 'Bassin RH', 'Gerwin BL', 'Duran-Troise G'],
#  ['Ashcroft SJ'],
#  ['Vallet-Strouve C', 'Rat L', 'Sala-Trepat JM'],
#  ['Blicher-Toft M', 'Hummer L'],
#  ['Ahne W'],
#  ['Schonberger LB', 'McGowan JE Jr', 'Gregg MB'],
#  ['Menuck LS', 'Brahme F', 'Amberg J', 'Sherr HP'],
#  ['Alexander M', 'van den Bogaert N', 'Fondu P'],
#  ['Jay E', 'Wu R'],
#  ['Bartlett JR', 'Doty RW', 'Lee BB Sr', 'Sakakura H'],
#  ['Nakai T', 'Otto PS', 'Kennedy DL', 'Whayne TF Jr'],
#  ['Non DP Jr', 'Lang WR', 'Patchefsky A', 'Takeda M'],
#  ['Jelaso DV', 'Hirschfield JS'],
#  ['Scott MB', 'Goldstein AM', 'Onofrio RC', 'Cosgrove MD'],
#  ['Goldstein IM', 'Kaplan HB', 'Radin A', 'Frosch M'],
#  ['Travaglini EC', 'Dube DK', 'Surrey S', 'Loeb LA'],
#  ['Leiden JM', 'Buttyan R', 'Spear PG'],
#  ['Yang SS', 'Heidelberger KP', 'Bernstein J'],
#  ['Idahl LA', 'Lernmark A', 'Sehlin J', 'Täljedal IB'],
#  ['Singer DS', 'Singer MF'],
#  ['Stahl P',
#   'Six H',
#   'Rodman JS',
#   'Schlesinger P',
#   'Tulsiani DR',
#   'Touster O'],
#  ['Barriere H', 'Berger M', 'Billaudel S'],
#  ['Bucana C',
#   'Hoyer LC',
#   'Hobbs B',
#   'Breesman S',
#   'McDaniel M',
#   'Hanna MG Jr'],
#  ['Beighton P', 'Davidson J', 'Durr L', 'Hamersma H'],
#  [],
#  ['Strano AJ'],
#  ['Gottlieb G'],
#  ['Beighton P', 'Cremin BJ', 'Hamersma H'],
#  ['Lippmann W'],
#  ['Heller RM', 'Sang Oh K', 'Kaizer H', 'Musikabhumma A'],
#  ['Frable WJ', 'Frable MA', 'Seney FD Jr'],
#  ['Kuroyanagi Y', 'Sawada M', 'Hidemura R', 'Aoki S', 'Kato H'],
#  ['Meyer AA', 'Enker WE', 'Jacobitz JL', 'Wissler RW', 'Craft K'],
#  ['Stephens HR', 'Sandborn EB'],
#  ['Riordan JF', 'McElvany KD', 'Borders CL Jr'],
#  ['Marquez JF', 'James EC', 'Gardner RJ'],
#  ['Brown RA', 'Hukins DW', 'Weiss JB', 'Twose TM'],
#  ['Bevers EM', 'Singal SA', 'Op den Kamp JA', 'van Deenen LL'],
#  ['Sprössig M', 'Wutzler P', 'Färber I', 'Schweizer H', 'Schneider J'],
#  ['Trehub A'],
#  ['Hevron JE Jr'],
#  ['Harwood R', 'Merry AH', 'Woolley DE', 'Grant ME', 'Jackson DS'],
#  ['Yeaman SJ', 'Cohen P', 'Watson DC', 'Dixon GH'],
#  ['Lowenfels AB', 'Anderson ME'],
#  ['Aurelian L', 'Strnad BC', 'Smith MF'],
#  ['Soloff MS', 'Schroeder BT', 'Chakraborty J', 'Pearlmutter AF'],
#  ['Walter P'],
#  ['Klein G'],
#  ['Klein G'],
#  ['May PB Jr'],
#  ['Rickinson AB', 'Crawford D', 'Epstein MA'],
#  ['Bylund DB', 'Charness ME', 'Snyder SH'],
#  ['Cullen GC', 'Luce CM', 'Shannon GM'],
#  ['Klein G', 'Klein E'],
#  ['Klein G', 'Klein E'],
#  ['Morrow CP',
#   'Kletzky OA',
#   'Disaia PJ',
#   'Townsend DE',
#   'Mishell DR',
#   'Nakamura RM'],
#  ['Nowotny A', 'Butler RC', 'Grohsman J', 'Keebler C'],
#  ['Binnick AN', 'Spencer SK', 'Dennison WL Jr', 'Horton ES'],
#  ['Wadbrook DG', 'Ring C', 'Meinhard EA'],
#  ['Sawyers JL'],
#  ['Hauschild AH', 'Gilbert RJ', 'Harmon SM', "O'Keeffe MF", 'Vahlefeld R'],
#  ['Witte ON', 'Baltimore D'],
#  ['Hailes J', 'Burger H'],
#  ['Langs DA', 'Erman M', 'DeTitta GT'],
#  ['Kopelovich L', 'Wolfe G'],
#  ['Lai PK'],
#  ['Centifanto YM', 'Zam ZS', 'Kaufman HE'],
#  ['Iwata A', 'Suzumura N', 'Ikegaya K'],
#  ['Lincoln TM', 'Corbin JD'],
#  ['Rose JK'],
#  ["Kondrat'eva TT", 'Petrova AS'],
#  ['Murray HW', 'Knox DL', 'Green WR', 'Susel RM'],
#  ['Simmons RL',
#   'Matas AJ',
#   'Rattazzi LC',
#   'Balfour HH Jr',
#   'Howard JR',
#   'Najarian JS'],
#  ['Ruysschaert JM', 'Tenenbaum A', 'Berliner C', 'Delmelle M'],
#  ['Bolognesi DP', 'Montelaro RC', 'Frank H', 'Schäfer W'],
#  ['Steele NP Jr', 'Foshee WS', 'Koch HF', 'Ledbetter EO'],
#  ['Szalaty H', 'Lobodzińska M', 'Albin M'],
#  ['Tjian R'],
#  ['Clemens R'],
#  ['Rodman JS', 'Schlesinger P', 'Stahl P'],
#  ['Donaldson JC', 'Kaminsky DB', 'Elliott RC'],
#  ['Rudolph RH'],
#  ['Smith D', 'Griffin JF'],
#  ['Swenson KH', 'Amon RB', 'Hanifin JM'],
#  ['Fidler IJ'],
#  ['Shupack JL', 'Berczeller PH', 'Stevens DM'],
#  ['Deligdisch L', 'Driscoll SG', 'Goldstein DP'],
#  ['Cho C', 'Rullis I', 'Rogers LS'],
#  ['Ogmundsdóttir HM', 'Weir DM', 'Marmion BP'],
#  ['Campbell GR', 'Chamley JH', 'Burnstock G'],
#  ['Rees RP'],
#  ['McCumber LJ', 'Clem LW'],
#  ['Spelsberg F', 'Landgraf R', 'Wirsching R', 'Heberer G'],
#  ['Sprinzl M', 'Siboska GE', 'Pedersen JA'],
#  ['Sahyoun N', 'Hock RA', 'Hollenberg MD'],
#  ['Burnett GB'],
#  ['Otto E', 'Bräuer D', 'Wilhelm M'],
#  ['Wikstrand CJ', 'Proctor JO', 'Hartsell SC', 'Haughton G'],
#  ['Oppenheimer JH', 'Coulombe P', 'Schwartz HL', 'Gutfeld NW'],
#  ['Eberle A', 'Kriwaczek VM', 'Schwyzer R'],
#  ['Rose JK'],
#  ['Sever JL'],
#  ['Cabañas MJ', 'Vázquez D', 'Modolell J'],
#  ['Harris M', 'Wells S', 'Vasudev KS'],
#  ['Darmon M', 'Barra J', 'Brachet P'],
#  ['Schidlovsky G', 'Shibley GP', 'Benton CV', 'Elser JE'],
#  ['Shortle D', 'Nathans D'],
#  ['Lautenberger JA',
#   'Kan NC',
#   'Lackey D',
#   'Linn S',
#   'Edgell MH',
#   'Hutchison CA 3rd'],
#  ['Chu LY', 'Rhoads RE'],
#  ['Best JD', 'Chisholm DJ', 'Alford FP'],
#  ['Bryan CS', 'Foster CM', 'Edwards WG'],
#  ['Kliuchareva TE', 'Kashkina LM', 'Deĭchman GI'],
#  ['Walters MN', 'Papadimitriou JM'],
#  ['Moreau M', 'Guerrier P', 'Dorée M'],
#  ['Risser R', 'Stockert E', 'Old LJ'],
#  ['Matsuo M', 'Huang CH', 'Huang LC'],
#  ['Talal N'],
#  ['Cozzutto C', 'De Bernardi B', 'Guarino M', 'Comelli A', 'Soave F'],
#  ['Salzman LA', 'Fabisch P', 'Parr R', 'Garon C', 'Wali T'],
#  ...]

# %% [markdown]
# Filtering results, to obain only papers since 1940:

# %%
papers_per_year_since_1940 = [ (y,count) for (y,count) in papers_per_year if y >= 1940 ]
years_since_1940 = [ y for (y,count) in papers_per_year_since_1940 ]
nr_papers_since_1940 = [ count for (y,count) in papers_per_year_since_1940 ]

print('Number of papers in the dataset published since 1940:')
print(sum(nr_papers_since_1940))
# Out:
# Number of papers in the dataset published since 1940:
# 481024

# %% [markdown]
# Creating a bar plot to visualize the results (using [matplotlib.pyplot.bar](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.bar)):

# %%
plt.bar(x=years_since_1940, height=nr_papers_since_1940, width=1.0)
plt.xlim(1940, 2024)
plt.xlabel('year')
plt.ylabel('nr. of papers');

# %% [markdown]
# Alternatively, we can get the same result by plotting it as a histogram with [matplotlib.pyplot.hist](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.hist):

# %%
plt.hist( x=[p.year for p in Summaries.values()], bins=range(1940,2026) );
plt.xlim(1940, 2025)
plt.xlabel('year')
plt.ylabel('number of papers');

# %% [markdown]
# ### Papers per Author

# %% [markdown]
# Here, we will obtain the distribution characterizing the number of papers published by an author.

# %%
# flattening the list of lists of authors:
flat_author_list = [ auth for paper in Summaries.values() for auth in paper.authors ]

nr_papers_by_author = Counter( flat_author_list )

# %%
print('Number of authors in the dataset with distinct names:')
print(len(nr_papers_by_author))
# Out:
# Number of authors in the dataset with distinct names:
# 868723

# %%
print('Top 50 authors with greatest number of papers:')
print(sorted(nr_papers_by_author.items(), key=lambda i:i[1], reverse=True)[:50])
# Out:
# Top 50 authors with greatest number of papers:
# [('Wang Y', 4390), ('Zhang Y', 4035), ('Li Y', 3572), ('Liu Y', 3188), ('Wang X', 2962), ('Wang J', 2951), ('Li J', 2795), ('Zhang X', 2655), ('Li X', 2512), ('Zhang J', 2485), ('Wang L', 2332), ('Zhang L', 2146), ('Wang H', 2106), ('Liu J', 1960), ('Liu X', 1949), ('Chen Y', 1947), ('Wang Z', 1926), ('Li H', 1887), ('Zhang H', 1821), ('Chen X', 1722), ('Zhang Z', 1689), ('Wang S', 1636), ('Li Z', 1604), ('Chen J', 1598), ('Yang Y', 1544), ('Li L', 1466), ('Yang J', 1440), ('Liu H', 1418), ('Li S', 1395), ('Zhao Y', 1322), ('Liu Z', 1321), ('Wang C', 1275), ('Li C', 1225), ('Chen L', 1217), ('Zhang W', 1216), ('Wang W', 1206), ('Zhang S', 1191), ('Zhou Y', 1158), ('Wang Q', 1141), ('Wu Y', 1133), ('Xu Y', 1115), ('Liu S', 1113), ('Li W', 1111), ('Li M', 1102), ('Liu L', 1093), ('Chen H', 1082), ('Zhang C', 1080), ('Huang Y', 1060), ('Chen Z', 1051), ('Yang X', 1027)]

# %% [markdown]
# Then we can create a histogram to visualize the results:

# %%
plt.hist( x=list(nr_papers_by_author.values()), bins=range(101), log=True )
plt.xlabel('number of papers authored')
plt.ylabel('number of authors');

# %% [markdown]
# ### Authors per Paper

# %% [markdown]
# Then we can make a similar analysis for the number of authors per paper:

# %%
plt.hist(x=[ len(p.authors) for p in Summaries.values() ], bins=range(20), align='left', density=True)
plt.xlabel('number of authors in one paper')
plt.ylabel('fraction of papers')
plt.xlim(-0.5, 15.5);

# %% [markdown]
# ### Words in Titles

# %% [markdown]
# And then we can have a first look into the words we find in titles (applying a very naive word splitting method for now):

# %%
words = [ word.lower() for paper in Summaries.values() for word in paper.title.split(' ') ]
word_counts = Counter(words)

print('Number of distinct words in the paper titles:')
print(len(word_counts))
# Out:
# Number of distinct words in the paper titles:
# 320755

# %% [markdown]
# ----------

# %% [markdown]
# # Tasks

# %% [markdown]
# **Your name:** Jaspreet Singh

# %% [markdown]
# ### Task 1
#
# Create a Python dictionary object that returns a set of all names of second authors (that is, the authors that appear second in the list of authors) for a given year. Name this dictionary `second_authors_at_year`. (You can use a [*defaultdict*](https://docs.python.org/3/library/collections.html#collections.defaultdict) with a default value of [*set*](https://docs.python.org/3/library/stdtypes.html#set-types-set-frozenset).) Demonstrate the working of this dictionary by showing the set of second authors for the year 1956.

# %%
unique_years = set(paper_years)
second_authors_at_year = {}
for year in unique_years:
    second_aut_per_year = []
    for k in Summaries.values():
        if(k.year == year):
            if len(k.authors) >= 2:
                second_aut_per_year.append(k.authors[1])
    second_authors_at_year[year] = set(second_aut_per_year)

         


# your code here

# %%
print(second_authors_at_year[1956])
# Out:
# {'WEINSTEIN M', 'FRAZIER SH', 'BUSH WR', 'JONES JD', 'HAKE HW', 'BUCKINGHAM RA', 'LABERGE DL', 'FELDMAN H', 'IVANOFF JC', 'JONA E', 'BAILEY DE', 'GLAS WW', 'EWING WH', 'NORDIN BE', 'VONDRASHEK SC', 'STEVENS D', 'ROWE A Jr', 'CONLEY CL', 'PLAZAK DJ', "O'LEARY JL", 'SHANBROM E', 'FRASER R', 'VON MIKULICZ-RADECKI F', "DI SANT'AGNESE PA", 'WYSO E', 'COSTELLO JO', 'VERRIEST G', 'ROSENZWEIG MR', 'BIERMAN HR'}

# %% [markdown]
# ### Task 2
#
# Based on the dictionary `second_authors_at_year` from exercise 1 above, create a plot for the years from 1956 until now that shows how many authors published at least one paper as second author in the given particular year.

# %%
second_authors_at_year_from_1956 = {year: author for year, author in second_authors_at_year.items() if year >= 1956}
count_auth_each_year = []
years = []
for year, authors in second_authors_at_year_from_1956.items():
    count_auth_each_year.append(len(authors))
    years.append(year)
    
plt.plot(years[:len(years)-1],count_auth_each_year[:len(count_auth_each_year)-1]) 
## -2025 as a year
plt.ylabel("Frequency")
plt.xlabel("number of unique (second) authors in a given year")
plt.show()

# %% [markdown]
# ### Task 3
#
# Print out the top 10 most often occurring words in the papers' titles together with their frequency, in descending order with respect to the frequency. Filter out words that are only one, two, three or four characters long, like `a` or `of` or `the` or `from`, to only show words that have five or more characters. Use the data structures created above (in the sections before the tasks).

# %%
# your code here 
filtered_words = [word for word in words if len(word) > 4]

freq_words =Counter(filtered_words)

# %%
freq_words.most_common(10)
# Out:
# [('recognition', 63465),
#  ('using', 20737),
#  ('human', 18931),
#  ('protein', 15135),
#  ('based', 14106),
#  ('analysis', 13413),
#  ('detection', 12532),
#  ('visual', 12431),
#  ('memory', 11524),
#  ('effects', 11184)]

# %% [markdown]
# ### Task 4
#
# Calculate and plot (e.g. using [plt.plot](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.plot)) a graph of the frequency of the 200 most frequent words in titles of papers, from most frequent to least frequent, again only counting words of five or more characters. (For readability, don't show the actual words.) Make again use of the data structures created above.

# %%
top_200_words = freq_words.most_common(200)
frequencies = [freq for _, freq in top_200_words]
plt.plot(frequencies)
plt.title("Frequency of the 200 Most Frequent Words in in titles of papers")
plt.xlabel("Rank of most freq word")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Task 5
#
# What do you notice when looking at the top 10 most frequent words? Explain all types of words we find in this top-10 and why they show up here.

# %% [markdown]
# **Answer:**  We notice that it rapidly decreases after top 1, however this is obvious as we selected a subset of papers in Pubmed that contained "Recognition", so it is obvious that most of the names contains recognition. We also see that that the declining slope is not rapid anymore after the rank 25 , The frequency converges to a somewhat called lower bound. Furthermore on the type. The top 10 most frequent words in the subset of PubMed abstracts focused on "Recognition" and Pubmed contains biomedical research papers. Words like using and based can be seen as methodology, the research methods and approaches commonly used. Words like such as analysis, detection, and effects shows how the research processes are conducted and what outcomes are evaluated.  Words like human, protein, visual, and memory can be seen as the study areas human (biology/health), protein (molecular/ biochemical processes), and visual and memory (cognitive and visual recognition studies).

# %% [markdown]
# # Submission

# %% [markdown]
# Submit the answers to the assignment via Canvas as a modified version of this Notebook file (file with `.ipynb` extension) that includes your code and your answers.
#
# Before submitting, restart the kernel and re-run the complete code (**Kernel > Restart & Run All**), and then check whether your assignment code still works as expected.
#
# Don't forget to add your name, and remember that the assignments have to be done **individually**, and that code sharing or copying are **strictly forbidden** and will be punished.
